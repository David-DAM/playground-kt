// %% [markdown]
// # Basic Kotlin Example
//
// This notebook demonstrates how to execute Kotlin code interactively.

// %%
val firstNumber = 2
val secondNumber = 2

val sum = firstNumber + secondNumber

// %%
println("The result of $firstNumber + $secondNumber is $sum")
// Out:
// The result of 2 + 2 is 4

// %%
sum
// Out:
// 4
